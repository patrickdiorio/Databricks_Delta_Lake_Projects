# %%
# %sql
DROP TABLE IF EXISTS hotel;

-- Carregaato de arquivos Parquet sobre dados de hotel
CREATE TABLE hotel
USING parquet
PARTITIONED BY (Categoria)
SELECT _c0 as Ordem, _c1 as Tipo, _c2 as Situacao, _c3 as Tip_local, _c4 as Categoria, _c5 as Tip_Local2, _c6 as Tip_local3, _c7 as Acomodacao, _c8 as Cidade, _c9 as Pais, _c10 as Endereco, _c11 as Latitude, _c12 as Longitude, _c13 as Provincia, _c14 as CEP, _c15 as UF, _c16 as Data_estadia, _c17 as Revisao_texto, _c17 as Revisao_titulo, _c19 as Revisao_cidade, _c20 as Endereco_web, _c21 as Comentario_usuario, _c22 as Resumo, _c23 as Comentario2, _c24 as Comentario3, _c25 as Comentario4
FROM csv.`dbfs:/FileStore/tables/hotel/Datafiniti_Hotel_Reviews_Jun19.csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Fazendo uma contagem das principais categorias e comentarios
SELECT Categoria,Comentario2,Comentario3,count(*) as Total
FROM hotel
GROUP BY Categoria,Comentario2,Comentario3
ORDER BY Categoria,Total DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Categoria</th><th>Comentario2</th><th>Comentario3</th><th>Total</th></tr></thead><tbody><tr><td>Accommodation & Food Services</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or155-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>17</td></tr><tr><td>Accommodation & Food Services</td><td> and also the door is sliding</td><td> no locks. Made more for a couple than a family</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Philippines</td><td>Maria B</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> this one makes you feel at home and cared for. In terms of the most impressive of the staff</td><td> Kelly Nguyen stuck out and really went above and beyond. Thank you.""</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Els K</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> also the bathroom was very small</td><td> too. The air-condiitioning was the old-fashioned window ones</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>New Orleans</td><td>Louisiana</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>peterhP887MP</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> but I do apologize for the lack of written directions throughout your excursions. I have shared your experience with our staff and we will make sure to be as thorough as possible in the future. We hope to welcome you back to the Hotel Abri when your travels return you to the vibrant city of San Francisco!Yours in hospitality</td><td>Rob Brehant</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Utah</td><td>CarlPicc</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>NewYork</td><td>C4063RCerikag</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> comfortable hotel""</td><td>Toronto</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>California</td><td>STB3288</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> 1 block from the BART station</td><td> great if you are arriving from SFO</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Bellevue</td><td>Washington</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> so we went with Union Square. It was great to visit touristy areas but come back to local life. That said</td><td> Union Square is a huge shopping mecca so you could argue that its a commercial area. But the vibe feel much more local. This hotel is like staying Union Square in NY versus sleeping in Time Square...exactly how we wanted to experience San Fran.""</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Ohio</td><td>918debm</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>sjung_721731</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> cable car</td><td> and hopping on the train to get just about anywhere. I can't say enough about the front desk staff</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Mexico</td><td>analK4245MU</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Norway</td><td>gunnaro862</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Atlanta</td><td>Georgia</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> but there is room service available from 11am onwards. (there are great breakfast plac ...

# %%
# %sql
-- Criando a tabela Delta
DROP TABLE IF EXISTS hotel;
CREATE TABLE hotel
USING delta
PARTITIONED BY (categoria)
SELECT _c0 as Ordem, _c1 as Tipo, _c2 as Situacao, _c3 as Tip_local, _c4 as Categoria, _c5 as Tip_Local2, _c6 as Tip_local3, _c7 as Acomodacao, _c8 as Cidade, _c9 as Pais, _c10 as Endereco, _c11 as Latitude, _c12 as Longitude, _c13 as Provincia, _c14 as CEP, _c15 as UF, _c16 as Data_estadia, _c17 as Revisao_texto, _c17 as Revisao_titulo, _c19 as Revisao_cidade, _c20 as Endereco_web, _c21 as Comentario_usuario, _c22 as Resumo, _c23 as Comentario2, _c24 as Comentario3, _c25 as Comentario4
FROM csv.`dbfs:/FileStore/tables/hotel/Datafiniti_Hotel_Reviews_Jun19.csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
-- Otimizando a consulta da tabela Delta com o campo Pais, é importante que busque o campo que melhor otimiza
OPTIMIZE hotel ZORDER BY (Pais);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>metrics</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/hotel</td><td>List(4, 8, List(43737, 61957, 54447.0, 4, 217788), List(17944, 53453, 33619.875, 8, 268959), 20, List(minCubeSize(107374182400), List(0, 0), List(24, 510619), 0, List(8, 268959), 4, null), 1, 24, 16, false)</td></tr></tbody></table></div>

# %%
# %sql
-- Executando a consulta otimizada na tabela Delta
SELECT Categoria,Comentario2,Comentario3,count(*) as Total
FROM hotel
GROUP BY Categoria,Comentario2,Comentario3
ORDER BY Categoria,Total DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Categoria</th><th>Comentario2</th><th>Comentario3</th><th>Total</th></tr></thead><tbody><tr><td>Accommodation & Food Services</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or155-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>17</td></tr><tr><td>Accommodation & Food Services</td><td>Brussels</td><td>Belgium</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> though I don't need it. Refrigerator in the room! Victory for me. I have medical needs for one</td><td> hate shelling out extra</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Brookeville</td><td>Maryland</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> noisy on occasion</td><td> missed wake up calls</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> but could never fix it</td><td> so we thought it was our DVD. We spent the last day of our trip traveling back to where we made the purchase</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> subways/buses</td><td> and not too far from various attractions. Nice area to walk around in too.Dear slimmybim</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> the Gas Lamp area</td><td> PETCO Park and to the USS Midway. Very convenient to all locations. They have Valet parking and a restaurant on property although we did not use it. They also have a fitness area and a indoor pool.Steve</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>CedricM10100</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> we were greeted with a homely reception. This was our first Abri experience and we were very impressed with the room</td><td> hotel and your staff. Indy Shrestha</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> it was LOUD. Construction will go on for a while since they are building a bart station. There is a bar close by and the shouting/talking at night can be deafening. Ask for an inside room to avoid this disturbance. If you must have a suite</td><td> then bring ear plugs. Will return for sure!""</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> John and Ben</td><td> did a fine job! Breakfast is not included</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>Jackieboy014</td><td>""https://www.tripadvisor.com/Hotel_Review-g60750-d80423-Reviews-or145-Marriott_Vacation_Club_Pulse_San_Diego-San_Diego_California.html#REVIEWS</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>UnitedKingdom</td><td>835glynp</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>""Good location</td><td> staff nice</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> except in my room</td><td> which smelled fresh and clean.It was fun and restful</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> passports</td><td> iPads etc with it being a long trip</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> it was well-appointed and had a decent size bathroom and shower. The rooms had window AC/heat units</td><td> but they were thermostatically controlled</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> I can't so will avoid. My 125 turned into 158( plus usual taxes.) Just tell me upfront""</td><td>""Great location and clean. Small</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td>mariana728</td><td>""https://www.tripadvisor.com/Hotel_Review-g60713-d81165-Reviews-or475-Hotel_Abri-San_Francisco_California.html#REVIEWS</td><td>1</td></tr><tr><td>Accommodation & Food Services</td><td> this one makes you feel  ...
